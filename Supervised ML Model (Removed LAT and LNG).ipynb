# %% [markdown]
# ## Supervised Machine Learning Model

# %% [markdown]
# #### The purpose of this machine learning model is to explore if it is possible to predict if a Twitter user is a climate change believer, denier, or neutral towards climate change based on their location, temperature change of their area over the past 50 years, gender, and the topic of their Tweet. Social media is becoming more and more worldwide and is more widely used than most traditional government polls. Using social media data to uncover public opinion on important topics such as this can become a more accurate way to assess these opinions and uses less resources than traditional polling methods.

# %% [markdown]
# #### Google Colab Dependencies

# %%
#from google.colab import drive
#drive.mount('/content/drive/')

# %%
#import os
#Change the current working directory to the path of Google Cloud Drive
#path="/content/drive/My Drive/Colab Notebooks/"
#os.chdir(path)
#os.listdir(path)

# %% [markdown]
# #### Jupyter Notebook Dependencies

# %%
# Import all dependencies
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None 
from pathlib import Path
from collections import Counter
import sqlalchemy
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
import psycopg2
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import datetime

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from imblearn.ensemble import BalancedRandomForestClassifier
from config import password

# %% [markdown]
# ### Import the Data as a Dataframe and Perform Data Preprocessing

# %% [markdown]
# #### The data for this project is sourced from Kaggle: "The Climate Change Twitter Dataset"

# %% [markdown]
# #### PgAdmin Database Import

# %%
# Create the connection to postgres
#db_string = f"postgresql://postgres:{password}@127.0.0.1:5432/climate-change-twitter"

#Instantiate the engine
#engine = create_engine(db_string)

# Load the table as a dataframe
#cc_twitter_df = pd.read_sql('select * from climate_change_twitter', con=engine)
#cc_twitter_df

# %% [markdown]
# #### CSV File Import

# %%
# Load the data
cc_twitter_raw_df = pd.read_csv("../climate_change_twitter2.csv")
cc_twitter_raw_df.head(5)
# Out:
#                   created_at      id        lng        lat  \
# 0  2006-06-06 16:06:42+00:00    6132        NaN        NaN
# 1  2006-07-23 21:52:30+00:00   13275 -73.949582  40.650104
# 2  2006-08-29 01:52:30+00:00   23160        NaN        NaN
# 3  2006-11-07 02:46:52+00:00   57868        NaN        NaN
# 4  2006-11-27 14:27:43+00:00  304553        NaN        NaN
#
#                               topic  sentiment   stance     gender  \
# 0                  Weather Extremes  -0.097180  neutral     female
# 1                  Weather Extremes   0.575777  neutral  undefined
# 2                  Weather Extremes   0.500479  neutral       male
# 3                  Weather Extremes   0.032816  neutral       male
# 4  Importance of Human Intervantion  -0.090428  neutral       male
#
#    temperature_avg aggressiveness
# 0              NaN     aggressive
# 1        -1.114768     aggressive
# 2              NaN     aggressive
# 3              NaN     aggressive
# 4              NaN     aggressive

# %% [markdown]
# #### Preprocess Dataframe for Machine Learning Model

# %%
cc_twitter_raw_df.count()
# Out:
# created_at         15789411
# id                 15789411
# lng                 5307538
# lat                 5307538
# topic              15789411
# sentiment          15789411
# stance             15789411
# gender             15789411
# temperature_avg     5307538
# aggressiveness     15789411
# dtype: int64

# %%
# Drop the null rows
cc_twitter_nulldrop_df = cc_twitter_raw_df.dropna()
cc_twitter_nulldrop_df.head()
# Out:
#                    created_at       id         lng        lat  \
# 1   2006-07-23 21:52:30+00:00    13275  -73.949582  40.650104
# 7   2006-12-14 01:39:10+00:00  1092823 -122.419420  37.774930
# 8   2006-12-17 19:43:09+00:00  1278023  -79.791980  36.072640
# 9   2006-12-21 01:39:01+00:00  1455543 -121.805790  38.004920
# 11  2006-12-31 10:47:25+00:00  1893063   -1.902691  52.479699
#
#                                       topic  sentiment   stance     gender  \
# 1                          Weather Extremes   0.575777  neutral  undefined
# 7   Ideological Positions on Global Warming  -0.544195  neutral       male
# 8                          Weather Extremes  -0.565028   denier       male
# 9                          Weather Extremes   0.650960  neutral       male
# 11                         Weather Extremes   0.670905  neutral       male
#
#     temperature_avg  aggressiveness
# 1         -1.114768      aggressive
# 7          4.228540      aggressive
# 8          5.478175      aggressive
# 9         -1.652156  not aggressive
# 11         4.864521      aggressive

# %%
# Clean any spaces in column names to avoid errors
cc_twitter_nulldrop_df.columns = cc_twitter_nulldrop_df.columns.str.strip()

# %%
# Encode stance column
# This is the target column for the machine learning model
cc_twitter_nulldrop_df['stance'] = cc_twitter_nulldrop_df['stance'].replace(['neutral'], 0)
cc_twitter_nulldrop_df['stance'] = cc_twitter_nulldrop_df['stance'].replace(['believer'], 1)
cc_twitter_nulldrop_df['stance'] = cc_twitter_nulldrop_df['stance'].replace(['denier'], 2)
cc_twitter_endocedstance_df = cc_twitter_nulldrop_df
cc_twitter_endocedstance_df.head(5)
# Out:
#                    created_at       id         lng        lat  \
# 1   2006-07-23 21:52:30+00:00    13275  -73.949582  40.650104
# 7   2006-12-14 01:39:10+00:00  1092823 -122.419420  37.774930
# 8   2006-12-17 19:43:09+00:00  1278023  -79.791980  36.072640
# 9   2006-12-21 01:39:01+00:00  1455543 -121.805790  38.004920
# 11  2006-12-31 10:47:25+00:00  1893063   -1.902691  52.479699
#
#                                       topic  sentiment  stance     gender  \
# 1                          Weather Extremes   0.575777       0  undefined
# 7   Ideological Positions on Global Warming  -0.544195       0       male
# 8                          Weather Extremes  -0.565028       2       male
# 9                          Weather Extremes   0.650960       0       male
# 11                         Weather Extremes   0.670905       0       male
#
#     temperature_avg  aggressiveness
# 1         -1.114768      aggressive
# 7          4.228540      aggressive
# 8          5.478175      aggressive
# 9         -1.652156  not aggressive
# 11         4.864521      aggressive

# %%
# Isolate the date from timestamp and create new column to store the date
cc_twitter_endocedstance_df['created_at'] = pd.to_datetime(cc_twitter_endocedstance_df['created_at'])
cc_twitter_endocedstance_df['date'] = cc_twitter_endocedstance_df['created_at'].dt.date
cc_twitter_date_df = cc_twitter_endocedstance_df
cc_twitter_date_df.head()
# Out:
#                   created_at       id         lng        lat  \
# 1  2006-07-23 21:52:30+00:00    13275  -73.949582  40.650104
# 7  2006-12-14 01:39:10+00:00  1092823 -122.419420  37.774930
# 8  2006-12-17 19:43:09+00:00  1278023  -79.791980  36.072640
# 9  2006-12-21 01:39:01+00:00  1455543 -121.805790  38.004920
# 11 2006-12-31 10:47:25+00:00  1893063   -1.902691  52.479699
#
#                                       topic  sentiment  stance     gender  \
# 1                          Weather Extremes   0.575777       0  undefined
# 7   Ideological Positions on Global Warming  -0.544195       0       male
# 8                          Weather Extremes  -0.565028       2       male
# 9                          Weather Extremes   0.650960       0       male
# 11                         Weather Extremes   0.670905       0       male
#
#     temperature_avg  aggressiveness        date
# 1         -1.114768      aggressive  2006-07-23
# 7          4.228540      aggressive  2006-12-14
# 8          5.478175      aggressive  2006-12-17
# 9         -1.652156  not aggressive  2006-12-21
# 11         4.864521      aggressive  2006-12-31

# %%
# Drop "created_at" column
cc_twitter_date_df = cc_twitter_date_df.drop('created_at', axis=1)

# %%
# Convert date object to string for ml model
cc_twitter_date_df['date'] = cc_twitter_date_df['date'].astype(str).apply(lambda x: x.replace('-', '')).astype(int)

# %%
# Drop ID column; it does not contain useful information for the model
cc_twitter_date_df = cc_twitter_date_df.drop(["id"], axis=1)

# %%
# Import cleaned dataframe as a CSV file
cc_twitter_date_df.to_csv("../climate_change_twitter_cleaned.csv")

# %%
cc_twitter_date_df = cc_twitter_date_df.drop(["sentiment"], axis=1)

# %%
# Import cleaned dataframe back into PGAdmin

# %%
# Encode topic, gender, and aggressiveness to numerical values
cc_twitter_df = pd.get_dummies(cc_twitter_date_df, columns=['topic', 'gender', 'aggressiveness'])
cc_twitter_df.head(10)
# Out:
#            lng        lat  stance  temperature_avg      date  \
# 1   -73.949582  40.650104       0        -1.114768  20060723
# 7  -122.419420  37.774930       0         4.228540  20061214
# 8   -79.791980  36.072640       2         5.478175  20061217
# 9  -121.805790  38.004920       0        -1.652156  20061221
# 11   -1.902691  52.479699       0         4.864521  20061231
# 12  -73.949582  40.650104       0        15.600876  20070106
# 15   -0.125740  51.508530       0         4.908487  20070108
# 21   -0.127647  51.507322       0         4.598470  20070110
# 22   -0.127647  51.507322       0         4.598470  20070110
# 23   -0.127647  51.507322       1         4.702218  20070111
#
#     topic_Donald Trump versus Science  topic_Global stance  \
# 1                                   0                    0
# 7                                   0                    0
# 8                                   0                    0
# 9                                   0                    0
# 11                                  0                    0
# 12                                  0                    0
# 15                                  0                    0
# 21                                  0                    1
# 22                                  0                    1
# 23                                  0                    0
#
#     topic_Ideological Positions on Global Warming  \
# 1                                               0
# 7                                               1
# 8                                               0
# 9                                               0
# 11                                              0
# 12                                              0
# 15                                              0
# 21                                              0
# 22                                              0
# 23                                              0
#
#     topic_Impact of Resource Overconsumption  \
# 1                                          0
# 7                                          0
# 8                                          0
# 9                                          0
# 11                                         0
# 12                                         0
# 15                                         1
# 21                                         0
# 22                                         0
# 23                                         0
#
#     topic_Importance of Human Intervantion  topic_Politics  \
# 1                                        0               0
# 7                                        0               0
# 8                                        0               0
# 9                                        0               0
# 11                                       0               0
# 12                                       0               0
# 15                                       0               0
# 21                                       0               0
# 22                                       0               0
# 23                                       1               0
#
#     topic_Seriousness of Gas Emissions  \
# 1                                    0
# 7                                    0
# 8                                    0
# 9                                    0
# 11                                   0
# 12                                   0
# 15                                   0
# 21                                   0
# 22                                   0
# 23                                   0
#
#     topic_Significance of Pollution Awareness Events  \
# 1                                                  0
# 7                                                  0
# 8                                                  0
# 9                                                  0
# 11                                                 0
# 12                                                 0
# 15                                                 0
# 21                                                 0
# 22                                                 0
# 23                                                 0
#
#     topic_Undefined / One Word Hashtags  topic_Weather Extremes  \
# 1                                     0                       1
# 7                                     0                       0
# 8                                     0                       1
# 9                                     0                       1
# 11                                    0                       1
# 12                                    0                       1
# 15                                    0                       0
# 21                                    0                       0
# 22                                    0                       0
# 23                                    0                       0
#
#     gender_female  gender_male  gender_undefined  aggressiveness_aggressive  \
# 1               0            0                 1                          1
# 7               0            1                 0                          1
# 8               0            1                 0                          1
# 9               0            1                 0                          0
# 11              0            1                 0                          1
# 12              0            1                 0                          1
# 15              0            0                 1                          1
# 21              0            1                 0                          1
# 22              0            1                 0                          1
# 23              0            1                 0                          0
#
#     aggressiveness_not aggressive
# 1                               0
# 7                               0
# 8                               0
# 9                               1
# 11                              0
# 12                              0
# 15                              0
# 21                              0
# 22                              0
# 23                              1

# %%
cc_twitter_df.to_csv("../climate_change_twitter_cleaned2.csv")

# %% [markdown]
# #### Split data into features (X and y)

# %%
# Create the X features
X = cc_twitter_df.drop(["stance"], axis=1)

# %%
# Isolate the target
y = cc_twitter_df['stance']

# %%
# Check the features are correct
X.head()
# Out:
#            lng        lat  temperature_avg      date  \
# 1   -73.949582  40.650104        -1.114768  20060723
# 7  -122.419420  37.774930         4.228540  20061214
# 8   -79.791980  36.072640         5.478175  20061217
# 9  -121.805790  38.004920        -1.652156  20061221
# 11   -1.902691  52.479699         4.864521  20061231
#
#     topic_Donald Trump versus Science  topic_Global stance  \
# 1                                   0                    0
# 7                                   0                    0
# 8                                   0                    0
# 9                                   0                    0
# 11                                  0                    0
#
#     topic_Ideological Positions on Global Warming  \
# 1                                               0
# 7                                               1
# 8                                               0
# 9                                               0
# 11                                              0
#
#     topic_Impact of Resource Overconsumption  \
# 1                                          0
# 7                                          0
# 8                                          0
# 9                                          0
# 11                                         0
#
#     topic_Importance of Human Intervantion  topic_Politics  \
# 1                                        0               0
# 7                                        0               0
# 8                                        0               0
# 9                                        0               0
# 11                                       0               0
#
#     topic_Seriousness of Gas Emissions  \
# 1                                    0
# 7                                    0
# 8                                    0
# 9                                    0
# 11                                   0
#
#     topic_Significance of Pollution Awareness Events  \
# 1                                                  0
# 7                                                  0
# 8                                                  0
# 9                                                  0
# 11                                                 0
#
#     topic_Undefined / One Word Hashtags  topic_Weather Extremes  \
# 1                                     0                       1
# 7                                     0                       0
# 8                                     0                       1
# 9                                     0                       1
# 11                                    0                       1
#
#     gender_female  gender_male  gender_undefined  aggressiveness_aggressive  \
# 1               0            0                 1                          1
# 7               0            1                 0                          1
# 8               0            1                 0                          1
# 9               0            1                 0                          0
# 11              0            1                 0                          1
#
#     aggressiveness_not aggressive
# 1                               0
# 7                               0
# 8                               0
# 9                               1
# 11                              0

# %%
# Check the target is correct
y
# Out:
# 1           0
# 7           0
# 8           2
# 9           0
# 11          0
#            ..
# 15789396    1
# 15789404    1
# 15789405    0
# 15789407    1
# 15789408    0
# Name: stance, Length: 5307538, dtype: int64

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 1    3947378
# 0     994843
# 2     365317
# Name: stance, dtype: int64

# %%
# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)

# %% [markdown]
# ### Run the Random Forest Model with Entire Dataframe

# %%
# Instantiate a random forest classifier model
# n_estimators are set to 100 because
# random_state set to 78 because
rf_model = BalancedRandomForestClassifier(n_estimators=100, random_state=78)

# Fit the model
rf_model = rf_model.fit(X_train, y_train)

# %%
# Make predictions using the testing data on the trained model
predictions = rf_model.predict(X_test)

# %%
# Calculate the accuracy score of the model using the testing data
acc_score = balanced_accuracy_score(y_test, predictions)
acc_score
# Out:
# 0.5658951745406728

# %%
# Print the classification report of this model
print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.37      0.49      0.81      0.42      0.63      0.38    248765
#           1       0.88      0.60      0.77      0.72      0.68      0.46    986618
#           2       0.17      0.60      0.79      0.27      0.69      0.47     91502
#
# avg / total       0.74      0.58      0.78      0.63      0.67      0.44   1326885

# %%
# Sort the features by importance
features = sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
for feature in features:
    print(f"{feature[1]}: ({feature[0]})")
# Out:
# date: (0.3185286700722781)
# temperature_avg: (0.2078205448594281)
# lng: (0.19281436761219878)
# lat: (0.18746585102481556)
# topic_Donald Trump versus Science: (0.021569556114914918)
# topic_Weather Extremes: (0.015105682608740064)
# topic_Global stance: (0.011947789433995694)
# aggressiveness_aggressive: (0.005736509755611559)
# aggressiveness_not aggressive: (0.004904539855575742)
# topic_Ideological Positions on Global Warming: (0.004747711291156033)
# topic_Undefined / One Word Hashtags: (0.004667787259858081)
# topic_Importance of Human Intervantion: (0.004375945728691927)
# topic_Seriousness of Gas Emissions: (0.003826706901980601)
# gender_male: (0.003386001037768265)
# gender_female: (0.0032027012901892312)
# topic_Significance of Pollution Awareness Events: (0.0031566775996044487)
# topic_Politics: (0.002788220207465016)
# topic_Impact of Resource Overconsumption: (0.0025364853013999855)
# gender_undefined: (0.0014182520443279084)

# %% [markdown]
# #### This first Random Forest model is resulting in a low accuracy score, telling us that it is not likely (just higher than a 50/50 chance) of predicting an individual's stance based on their location, average temperature change of the area, their sentiment, gender, and topic of tweet. Now we will test dropping certain features and resulting different combinations of features to see if the model's accuracy changes based on the inputs.

# %% [markdown]
# ### Random Forest Model without Topic Columns

# %% [markdown]
# #### Preprocess dataframe to drop "topic" column

# %%
# Check dataframe from before topic was encoded
cc_twitter_date_df
# Out:
#                  lng        lat                                    topic  \
# 1         -73.949582  40.650104                         Weather Extremes
# 7        -122.419420  37.774930  Ideological Positions on Global Warming
# 8         -79.791980  36.072640                         Weather Extremes
# 9        -121.805790  38.004920                         Weather Extremes
# 11         -1.902691  52.479699                         Weather Extremes
# ...              ...        ...                                      ...
# 15789396  -65.957390  18.380780                            Global stance
# 15789404 -118.191604  33.769016                            Global stance
# 15789405    5.337804  50.930374            Undefined / One Word Hashtags
# 15789407 -118.243680  34.052230                            Global stance
# 15789408  100.501440  13.753980                                 Politics
#
#           stance     gender  temperature_avg  aggressiveness      date
# 1              0  undefined        -1.114768      aggressive  20060723
# 7              0       male         4.228540      aggressive  20061214
# 8              2       male         5.478175      aggressive  20061217
# 9              0       male        -1.652156  not aggressive  20061221
# 11             0       male         4.864521      aggressive  20061231
# ...          ...        ...              ...             ...       ...
# 15789396       1       male        -0.164199  not aggressive  20191001
# 15789404       1       male        -2.132015  not aggressive  20191001
# 15789405       0       male         6.402293  not aggressive  20191001
# 15789407       1     female        -3.126811  not aggressive  20191001
# 15789408       0     female        -0.364467  not aggressive  20191001
#
# [5307538 rows x 8 columns]

# %%
# Drop the topic column
cc_twitter_notopic_df = cc_twitter_date_df.drop(["topic"], axis=1)

# %%
# Encode gender and aggressiveness to numerical values
cc_twitter_notopic_df = pd.get_dummies(cc_twitter_notopic_df, columns=['gender', 'aggressiveness'])
cc_twitter_notopic_df.head(5)
# Out:
#            lng        lat  stance  temperature_avg      date  gender_female  \
# 1   -73.949582  40.650104       0        -1.114768  20060723              0
# 7  -122.419420  37.774930       0         4.228540  20061214              0
# 8   -79.791980  36.072640       2         5.478175  20061217              0
# 9  -121.805790  38.004920       0        -1.652156  20061221              0
# 11   -1.902691  52.479699       0         4.864521  20061231              0
#
#     gender_male  gender_undefined  aggressiveness_aggressive  \
# 1             0                 1                          1
# 7             1                 0                          1
# 8             1                 0                          1
# 9             1                 0                          0
# 11            1                 0                          1
#
#     aggressiveness_not aggressive
# 1                               0
# 7                               0
# 8                               0
# 9                               1
# 11                              0

# %% [markdown]
# #### Split data into features (X and y)

# %%
# Create the X features
X = cc_twitter_notopic_df.drop(["stance"], axis=1)

# %%
# Isolate the target
y = cc_twitter_notopic_df['stance']

# %%
# Check the features are correct
X.head()
# Out:
#            lng        lat  temperature_avg      date  gender_female  \
# 1   -73.949582  40.650104        -1.114768  20060723              0
# 7  -122.419420  37.774930         4.228540  20061214              0
# 8   -79.791980  36.072640         5.478175  20061217              0
# 9  -121.805790  38.004920        -1.652156  20061221              0
# 11   -1.902691  52.479699         4.864521  20061231              0
#
#     gender_male  gender_undefined  aggressiveness_aggressive  \
# 1             0                 1                          1
# 7             1                 0                          1
# 8             1                 0                          1
# 9             1                 0                          0
# 11            1                 0                          1
#
#     aggressiveness_not aggressive
# 1                               0
# 7                               0
# 8                               0
# 9                               1
# 11                              0

# %%
# Check the target is correct
y
# Out:
# 1           0
# 7           0
# 8           2
# 9           0
# 11          0
#            ..
# 15789396    1
# 15789404    1
# 15789405    0
# 15789407    1
# 15789408    0
# Name: stance, Length: 5307538, dtype: int64

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 1    3947378
# 0     994843
# 2     365317
# Name: stance, dtype: int64

# %%
# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)

# %% [markdown]
# #### Run the Random Forest Model

# %%
# Instantiate a random forest classifier model
# n_estimators are set to 100 because
# random_state set to 78 because
rf_model = BalancedRandomForestClassifier(n_estimators=100, random_state=78)

# Fit the model
rf_model = rf_model.fit(X_train, y_train)

# %%
# Make predictions using the testing data on the trained model
predictions = rf_model.predict(X_test)

# %%
# Calculate the accuracy score of the model using the testing data
acc_score = balanced_accuracy_score(y_test, predictions)
acc_score
# Out:
# 0.5008710040015741

# %%
# Print the classification report of this model
print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.31      0.45      0.77      0.37      0.59      0.33    248765
#           1       0.85      0.52      0.74      0.65      0.62      0.38    986618
#           2       0.13      0.53      0.74      0.21      0.63      0.39     91502
#
# avg / total       0.70      0.51      0.75      0.57      0.62      0.37   1326885

# %%
# Sort the features by importance
features = sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
for feature in features:
    print(f"{feature[1]}: ({feature[0]})")
# Out:
# date: (0.3399185722339077)
# temperature_avg: (0.23203490900601212)
# lng: (0.20795686315416373)
# lat: (0.20011269798680761)
# aggressiveness_aggressive: (0.005867564873592921)
# aggressiveness_not aggressive: (0.005714131221335128)
# gender_male: (0.0038743907454482926)
# gender_female: (0.00315123449683753)
# gender_undefined: (0.0013696362818947847)

# %%
cc_twitter_df
# Out:
#                  lng        lat  stance  temperature_avg      date  \
# 1         -73.949582  40.650104       0        -1.114768  20060723
# 7        -122.419420  37.774930       0         4.228540  20061214
# 8         -79.791980  36.072640       2         5.478175  20061217
# 9        -121.805790  38.004920       0        -1.652156  20061221
# 11         -1.902691  52.479699       0         4.864521  20061231
# ...              ...        ...     ...              ...       ...
# 15789396  -65.957390  18.380780       1        -0.164199  20191001
# 15789404 -118.191604  33.769016       1        -2.132015  20191001
# 15789405    5.337804  50.930374       0         6.402293  20191001
# 15789407 -118.243680  34.052230       1        -3.126811  20191001
# 15789408  100.501440  13.753980       0        -0.364467  20191001
#
#           topic_Donald Trump versus Science  topic_Global stance  \
# 1                                         0                    0
# 7                                         0                    0
# 8                                         0                    0
# 9                                         0                    0
# 11                                        0                    0
# ...                                     ...                  ...
# 15789396                                  0                    1
# 15789404                                  0                    1
# 15789405                                  0                    0
# 15789407                                  0                    1
# 15789408                                  0                    0
#
#           topic_Ideological Positions on Global Warming  \
# 1                                                     0
# 7                                                     1
# 8                                                     0
# 9                                                     0
# 11                                                    0
# ...                                                 ...
# 15789396                                              0
# 15789404                                              0
# 15789405                                              0
# 15789407                                              0
# 15789408                                              0
#
#           topic_Impact of Resource Overconsumption  \
# 1                                                0
# 7                                                0
# 8                                                0
# 9                                                0
# 11                                               0
# ...                                            ...
# 15789396                                         0
# 15789404                                         0
# 15789405                                         0
# 15789407                                         0
# 15789408                                         0
#
#           topic_Importance of Human Intervantion  topic_Politics  \
# 1                                              0               0
# 7                                              0               0
# 8                                              0               0
# 9                                              0               0
# 11                                             0               0
# ...                                          ...             ...
# 15789396                                       0               0
# 15789404                                       0               0
# 15789405                                       0               0
# 15789407                                       0               0
# 15789408                                       0               1
#
#           topic_Seriousness of Gas Emissions  \
# 1                                          0
# 7                                          0
# 8                                          0
# 9                                          0
# 11                                         0
# ...                                      ...
# 15789396                                   0
# 15789404                                   0
# 15789405                                   0
# 15789407                                   0
# 15789408                                   0
#
#           topic_Significance of Pollution Awareness Events  \
# 1                                                        0
# 7                                                        0
# 8                                                        0
# 9                                                        0
# 11                                                       0
# ...                                                    ...
# 15789396                                                 0
# 15789404                                                 0
# 15789405                                                 0
# 15789407                                                 0
# 15789408                                                 0
#
#           topic_Undefined / One Word Hashtags  topic_Weather Extremes  \
# 1                                           0                       1
# 7                                           0                       0
# 8                                           0                       1
# 9                                           0                       1
# 11                                          0                       1
# ...                                       ...                     ...
# 15789396                                    0                       0
# 15789404                                    0                       0
# 15789405                                    1                       0
# 15789407                                    0                       0
# 15789408                                    0                       0
#
#           gender_female  gender_male  gender_undefined  \
# 1                     0            0                 1
# 7                     0            1                 0
# 8                     0            1                 0
# 9                     0            1                 0
# 11                    0            1                 0
# ...                 ...          ...               ...
# 15789396              0            1                 0
# 15789404              0            1                 0
# 15789405              0            1                 0
# 15789407              1            0                 0
# 15789408              1            0                 0
#
#           aggressiveness_aggressive  aggressiveness_not aggressive
# 1                                 1                              0
# 7                                 1                              0
# 8                                 1                              0
# 9                                 0                              1
# 11                                1                              0
# ...                             ...                            ...
# 15789396                          0                              1
# 15789404                          0                              1
# 15789405                          0                              1
# 15789407                          0                              1
# 15789408                          0                              1
#
# [5307538 rows x 20 columns]

# %%
# Create the X features
cc_twitter_df_no_location = cc_twitter_df.drop(["lat"], axis=1)

# %%
cc_twitter_df_no_location = cc_twitter_df_no_location.drop(["lng"], axis=1)

# %%
X = cc_twitter_df_no_location.drop(["stance"], axis=1)

# %%
y = cc_twitter_df_no_location['stance']

# %%
X.head()
# Out:
#     temperature_avg      date  topic_Donald Trump versus Science  \
# 1         -1.114768  20060723                                  0
# 7          4.228540  20061214                                  0
# 8          5.478175  20061217                                  0
# 9         -1.652156  20061221                                  0
# 11         4.864521  20061231                                  0
#
#     topic_Global stance  topic_Ideological Positions on Global Warming  \
# 1                     0                                              0
# 7                     0                                              1
# 8                     0                                              0
# 9                     0                                              0
# 11                    0                                              0
#
#     topic_Impact of Resource Overconsumption  \
# 1                                          0
# 7                                          0
# 8                                          0
# 9                                          0
# 11                                         0
#
#     topic_Importance of Human Intervantion  topic_Politics  \
# 1                                        0               0
# 7                                        0               0
# 8                                        0               0
# 9                                        0               0
# 11                                       0               0
#
#     topic_Seriousness of Gas Emissions  \
# 1                                    0
# 7                                    0
# 8                                    0
# 9                                    0
# 11                                   0
#
#     topic_Significance of Pollution Awareness Events  \
# 1                                                  0
# 7                                                  0
# 8                                                  0
# 9                                                  0
# 11                                                 0
#
#     topic_Undefined / One Word Hashtags  topic_Weather Extremes  \
# 1                                     0                       1
# 7                                     0                       0
# 8                                     0                       1
# 9                                     0                       1
# 11                                    0                       1
#
#     gender_female  gender_male  gender_undefined  aggressiveness_aggressive  \
# 1               0            0                 1                          1
# 7               0            1                 0                          1
# 8               0            1                 0                          1
# 9               0            1                 0                          0
# 11              0            1                 0                          1
#
#     aggressiveness_not aggressive
# 1                               0
# 7                               0
# 8                               0
# 9                               1
# 11                              0

# %%
y
# Out:
# 1           0
# 7           0
# 8           2
# 9           0
# 11          0
#            ..
# 15789396    1
# 15789404    1
# 15789405    0
# 15789407    1
# 15789408    0
# Name: stance, Length: 5307538, dtype: int64

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 1    3947378
# 0     994843
# 2     365317
# Name: stance, dtype: int64

# %%
# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)

# %%
# Instantiate a random forest classifier model
# n_estimators are set to 100 because
# random_state set to 78 because
rf_model = BalancedRandomForestClassifier(n_estimators=100, random_state=78)

# Fit the model
rf_model = rf_model.fit(X_train, y_train)

# %%
# Make predictions using the testing data on the trained model
predictions = rf_model.predict(X_test)

# %%
# Calculate the accuracy score of the model using the testing data
acc_score = balanced_accuracy_score(y_test, predictions)
acc_score
# Out:
# 0.5426183914009868

# %%
# Print the classification report of this model
print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.35      0.48      0.79      0.40      0.62      0.37    248765
#           1       0.88      0.57      0.77      0.69      0.66      0.43    986618
#           2       0.15      0.58      0.77      0.24      0.67      0.43     91502
#
# avg / total       0.73      0.56      0.77      0.61      0.66      0.42   1326885

# %%
# Sort the features by importance
features = sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
for feature in features:
    print(f"{feature[1]}: ({feature[0]})")
# Out:
# temperature_avg: (0.5457351017013892)
# date: (0.3611751214549366)
# topic_Donald Trump versus Science: (0.022394965440873157)
# topic_Weather Extremes: (0.014364543009443054)
# topic_Global stance: (0.012973405087208213)
# aggressiveness_aggressive: (0.006056012384181289)
# aggressiveness_not aggressive: (0.005451570125294359)
# topic_Undefined / One Word Hashtags: (0.00515258684861825)
# topic_Importance of Human Intervantion: (0.00465988634292495)
# topic_Ideological Positions on Global Warming: (0.004433417348574839)
# topic_Seriousness of Gas Emissions: (0.003747125175978381)
# topic_Significance of Pollution Awareness Events: (0.0031309894854493338)
# gender_male: (0.002584063852849225)
# topic_Politics: (0.0025259609855983276)
# gender_female: (0.0024422529281400433)
# topic_Impact of Resource Overconsumption: (0.0023828882523507515)
# gender_undefined: (0.0007901095761900324)
